# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading data

# %%
data=pd.read_csv('auto-mpg.csv')
data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# # Histogram

# %%
plt.figure(figsize=(8,6))
plt.hist(data['mpg'],color='darkblue',rwidth=.7,density=True)
plt.title('Distribution of mpg',fontsize=16)
plt.xlabel('MPG')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### Create data1

# %%
data1=data.drop([32,126, 330, 336, 354, 374])
data1['horsepower']=data1['horsepower'].astype(float)

# %% [markdown]
# # Histogram

# %%
plt.hist(data1['mpg'])
plt.hist(data1['horsepower'])
# Out:
# (array([ 27.,  95., 120.,  44.,  19.,  47.,  13.,  14.,   5.,   8.]),
#  array([ 46. ,  64.4,  82.8, 101.2, 119.6, 138. , 156.4, 174.8, 193.2,
#         211.6, 230. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # KDE

# %%
data1[['mpg','horsepower']].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Scatter plot

# %%
plt.figure(figsize=(10,5))
plt.scatter(data1['horsepower'],data1['mpg'],s=12,c='blue',marker='o')
plt.title('Plot of HP vs MPG',fontsize=16)
plt.xlabel('HP')
plt.ylabel('MPG')
# Out:
# Text(0, 0.5, 'MPG')

# %% [markdown]
# # Pair plot

# %%
sns.pairplot(data)

# %%
slice_data=data[['mpg','origin','cylinders']]
sns.pairplot(slice_data)

# %% [markdown]
# # Heat map

# %%
sns.heatmap(slice_data.corr(),annot=True)
plt.yticks(rotation=360)
# Out:
# (array([0.5, 1.5, 2.5]),
#  [Text(0, 0.5, 'mpg'), Text(0, 1.5, 'origin'), Text(0, 2.5, 'cylinders')])

# %% [markdown]
# # Box plot

# %%
sns.boxplot(x='cylinders',y='mpg',data=data)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='mpg'>

# %% [markdown]
# # Strip plot

# %%
 sns.stripplot(data['mpg'])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mpg'>

# %% [markdown]
# # Swarm plot

# %%
sns.swarmplot(x='cylinders',y='mpg',data=data)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 14.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 23.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='cylinders', ylabel='mpg'>

# %% [markdown]
# # Violin plot

# %%
sns.violinplot(x='cylinders',y='mpg',data=data)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='mpg'>

# %% [markdown]
# # Count plot

# %%
sns.countplot(data['origin'])
plt.grid()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
